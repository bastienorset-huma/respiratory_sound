# %%
import os

import pandas as pd
import numpy as np

# %%
df_info = pd.read_csv('../../data/info_dataset.csv',index_col=0)

# %%
df_info['location'] = df_info.filename.apply(lambda x: x.split('_')[2])
df_info['sc'] = df_info.filename.apply(lambda x: x.split('_')[3])
df_info['idk'] = df_info.filename.apply(lambda x: x.split('_')[1])

# %%
df_info['wheeze_b'] = np.where(df_info['wheeze']>0,1,0)
df_info['crackle_b'] = np.where(df_info['crackle']>0,1,0)
df_info['both'] = np.where(df_info[['wheeze_b','crackle_b']].sum(axis=1)>0,1,0)
df_info['none'] = np.where(df_info[['wheeze_b','crackle_b']].sum(axis=1)==0,1,0)

# %%
df_info[df_info.recording_type == 'AKGC417L']
# Out:
#      Participant_ID   Age Sex  Adult BMI (kg/m2)  Child Weight (kg)  \
# 13            107.0  75.0   F               33.7                NaN
# 14            107.0  75.0   F               33.7                NaN
# 15            107.0  75.0   F               33.7                NaN
# 16            107.0  75.0   F               33.7                NaN
# 17            107.0  75.0   F               33.7                NaN
# ..              ...   ...  ..                ...                ...
# 867           213.0  58.0   F               24.7                NaN
# 868           213.0  58.0   F               24.7                NaN
# 869           213.0  58.0   F               24.7                NaN
# 870           213.0  58.0   F               24.7                NaN
# 871           213.0  58.0   F               24.7                NaN
#
#      Child Height (cm) Outcome                filename  wheeze  crackle  \
# 13                 NaN    COPD  107_2b3_Ar_mc_AKGC417L     7.0     25.0
# ...

# %%
df_info.groupby('location').sum()
# Out:
# /var/folders/xx/qddw26dx0174zw4hpmjq3gjh0000gn/T/ipykernel_30045/3385368913.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_info.groupby('location').sum()
#           Participant_ID     Age  Adult BMI (kg/m2)  Child Weight (kg)  \
# location
# Al               21230.0  8782.0            3328.04                0.0
# Ar               23411.0  9537.0            3619.38                0.0
# Ll               10607.0  4702.0            1712.62                0.0
# Lr               17513.0  7484.0            2780.08                0.0
# Pl               20538.0  8623.0            3196.96                0.0
# Pr               20432.0  8454.0            3157.74                0.0
# Tc               16692.0  6919.0            2564.56                0.0
#
# ...

# %%
df_info.groupby('sc').sum()
# Out:
# /var/folders/xx/qddw26dx0174zw4hpmjq3gjh0000gn/T/ipykernel_30045/3470220549.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_info.groupby('sc').sum()
#     Participant_ID      Age  Adult BMI (kg/m2)  Child Weight (kg)  \
# sc
# mc        115778.0  48247.0           17717.99                0.0
# sc         14645.0   6254.0            2641.39                0.0
#
#     Child Height (cm)  wheeze  crackle  wheeze_b  crackle_b  both  none
# sc
# mc                0.0  1423.0   8363.0       263        429   520   177
# sc                0.0   276.0    307.0        43         38    62    34
